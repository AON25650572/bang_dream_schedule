# %%
# !pip install requests

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
# WebサイトのURLを指定
# url = "https://www.crummy.com/software/BeautifulSoup/bs4/doc/"

# %%
# Requestsを利用してWebページを取得する
# r = requests.get(url)

# %%
# BeautifulSoupを利用してWebページを解析する
# soup = BeautifulSoup(r.text, "html.parser")

# %%
# soup.find_allを利用して、見出しのタイトルを取得する
# elems = soup.find_all("a", class_="reference internal")
# for e in elems:
#     print(e.getText())

# %%
# soup.__init__

# %% [markdown]
# なるほど！よく分からん！

# %% [markdown]
# 適当にやろう！助けてQiita先生！

# %% [markdown]
# https://qiita.com/itkr/items/513318a9b5b92bd56185

# %%
def niketa(num):
    """
    入力（int）を2ケタにする
    出力はstr
    """
    if 0 <= num < 10 and type(num) == int:
        return "0" + str(num)
    elif num < 100:
        return str(num)
    else:
        return None

# %%
year = 2021
month = 1
url = "https://bang-dream.com/news/schedule?ym="

url += str(year) + niketa(month)

# %%
url
# Out:
# 'https://bang-dream.com/news/schedule?ym=202101'

# %%
# Requestsを利用してWebページを取得する
r = requests.get(url)

# BeautifulSoupを利用してWebページを解析する
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup.find_all(class_="calendar")
# Out:
# [<div class="calendar">
#  <div class="calendarHead">
#  <div class="calendarHeadItem sunday">日</div>
#  <div class="calendarHeadItem">月</div>
#  <div class="calendarHeadItem">火</div>
#  <div class="calendarHeadItem">水</div>
#  <div class="calendarHeadItem">木</div>
#  <div class="calendarHeadItem">金</div>
#  <div class="calendarHeadItem saturday">土</div> </div>
#  <div class="calendarBody">
#  <div class="kvLoadingWrapper">
#  <div class="kvSlideLoading kvSlideLoadingTop">
#  <div class="kvSlideLoadingStar"><img alt="" src="/img/top/kv-slide-loading-star-icon.png"/></div>
#  <div class="kvSlideLoadingText"><img alt="Loading..." src="/img/top/kv-slide-loading-text.png"/></div>
#  </div>
#  </div>
#  <div class="calendarRow"><div class="calendarCell notCurrent"><div class="calendarCellDate">27<span>日曜日</span></div><div class="calendarCellContent"><a class="calendarItem isSp" href="https://bang-dream.bushimo.jp/character/maruyama-aya/" target="_blank">🍰丸山 彩　誕生日</a></div></div>
# ...

# %% [markdown]
# <div class="calendar">
#  <div class="calendarHead">
#  <div class="calendarHeadItem sunday">日</div>
#  <div class="calendarHeadItem">月</div>
#  <div class="calendarHeadItem">火</div>
#  <div class="calendarHeadItem">水</div>
#  <div class="calendarHeadItem">木</div>
#  <div class="calendarHeadItem">金</div>
#  <div class="calendarHeadItem saturday">土</div> </div>
#  <div class="calendarBody">
#  <div class="kvLoadingWrapper">
#  <div class="kvSlideLoading kvSlideLoadingTop">
#  <div class="kvSlideLoadingStar"><img alt="" src="/img/top/kv-slide-loading-star-icon.png"/></div>
#  <div class="kvSlideLoadingText"><img alt="Loading..." src="/img/top/kv-slide-loading-text.png"/></div>
#  </div>
#  </div>
#  <div class="calendarRow"><div class="calendarCell notCurrent"><div class="calendarCellDate">27<span>日曜日</span></div><div class="calendarCellContent"><a class="calendarItem isSp" href="https://bang-dream.bushimo.jp/character/maruyama-aya/" target="_blank">🍰丸山 彩　誕生日</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">28<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.nack5.co.jp/program/afterglow795/" target="_blank">📻《0:30》【第3回】Afterglowの夕焼けSTUDIO SPECIAL</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第216回】バンドリ！ポッピンラジオ！</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">29<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #37</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">30<span>水曜日</span></div><div class="calendarCellContent"><a class="calendarItem event isSp" href="https://bang-dream.com/events/cdj2021" target="_blank">【開催中止】🎤「COUNTDOWN JAPAN 20/21」Roselia出演</a>
#  <a class="calendarItem goods isSp" href="https://bushiroad-creative.com/items/2356" target="_blank">🎵《新発売》VOCAL COLLECTION 　丸山 彩 from Pastel＊Palettes</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Roselia/detail" target="_blank">📻【第162回】RoseliaのRADIO SHOUT!</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">31<span>木曜日</span></div><div class="calendarCellContent"><a class="calendarItem event isSp" href="https://bang-dream.com/events/cdj2021" target="_blank">【開催中止】🎤「COUNTDOWN JAPAN 20/21」Poppin'Party出演</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/ras/detail" target="_blank">📻【第101回】RAISE A SUILENのRADIO R･I･O･T</a>
#  <a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《22:00》バンドリ！TV LIVE  2020 #48</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">1<span>金曜日</span></div><div class="calendarCellContent"></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">2<span>土曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://bang-dream.com/news/1095">🎍《22:00》朝までバンドリ！TV 2021</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Afterglowplus/detail" target="_blank">📻【第14回】Afterglowの夕焼けSTUDIO＋</a></div></div>
#  <div class="calendarBelt" id="row0"></div></div> <div class="calendarRow"><div class="calendarCell"><div class="calendarCellDate">3<span>日曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://bang-dream.com/news/1095">🎍《22:00》朝までバンドリ！TV 2021</a>
#  <a class="calendarItem event isSp" href="https://twitter.com/bang_dream_info/status/1329702847760326656" target="_blank">📺《23:15》NHK総合テレビ「SONGS OF TOKYO FESTIVAL 2020」</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">4<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem event isSp" href="https://bang-dream.com/events/ruc2" target="_blank">🎫【申込締切】「Rausch und/and Craziness Ⅱ」ブシロードミュージックパスポート先行</a>
#  <a class="calendarItem event isSp" href="https://bang-dream.com/events/astralharmony" target="_blank">🎫【申込締切】「Astral Harmony」ブシロードミュージックパスポート先行</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第217回】バンドリ！ポッピンラジオ！</a>
#  <a class="calendarItem media isSp" href="https://www.1242.com/bang_dream/" target="_blank">📻《20:30》【第12回】BanG Dream! Presents RAISE A SUILEN のRADIO R･I･O･T</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">5<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #38</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">6<span>水曜日</span></div><div class="calendarCellContent"><a class="calendarItem release isSp" href="https://bang-dream.com/discographies/2285" target="_blank">💿Poppin'Party 16th Single「Photograph」</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Roselia/detail" target="_blank">📻【第163回】RoseliaのRADIO SHOUT!</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">7<span>木曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《22:00》バンドリ！TV LIVE 2021 #49</a>
#  <a class="calendarItem anime isSp" href="https://anime.bang-dream.com/2nd/" target="_blank">📺《23:00》アニメ「BanG Dream! 2nd Season」#1（再）</a>
#  <a class="calendarItem isSp" href="https://bang-dream.bushimo.jp/character/hazawa-tsugumi/" target="_blank">🍰羽沢つぐみ　誕生日</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">8<span>金曜日</span></div><div class="calendarCellContent"></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">9<span>土曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Afterglowplus/detail" target="_blank">📻【第15回】Afterglowの夕焼けSTUDIO＋</a></div></div>
#  <div class="calendarBelt" id="row1"></div></div> <div class="calendarRow"><div class="calendarCell"><div class="calendarCellDate">10<span>日曜日</span></div><div class="calendarCellContent"></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">11<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem event isSp" href="https://bang-dream.com/events/ruc_asharmo">⭐バンドリ！スペシャルイベント「らうくれ！」＆「あすはも！」</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第218回】バンドリ！ポッピンラジオ！</a>
#  <a class="calendarItem media isSp" href="https://anime.bang-dream.com/3rd/" target="_blank">📻《20:30》【第13回】BanG Dream! Presents RAISE A SUILENのRADIO R･I･O･T</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">12<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #39</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">13<span>水曜日</span></div><div class="calendarCellContent"><a class="calendarItem release isSp" href="https://bang-dream.com/discographies/2173" target="_blank">💿Morfonica 2nd Single「ブルームブルーム」</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Roselia/detail" target="_blank">📻【第164回】RoseliaのRADIO SHOUT!</a>
#  <a class="calendarItem isSp" href="https://anime.bang-dream.com/3rd/character/raise-a-suilen/#layer" target="_blank">🍰レイヤ　誕生日</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">14<span>木曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《22:00》バンドリ！TV LIVE  2021 #50</a>
#  <a class="calendarItem anime isSp" href="https://anime.bang-dream.com/2nd/" target="_blank">📺《23:00》アニメ「BanG Dream! 2nd Season」#2（再）</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">15<span>金曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">【放送延期】📺《21:00》Pastel＊PalettesのしゅわりんTV #19</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">16<span>土曜日</span></div><div class="calendarCellContent"><a class="calendarItem goods isSp" href="https://bushiroad-creative.com/184" target="_blank">🎵《プライズ新発売》イラストアクリルボード ハロー、ハッピーワールド！ 他</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Afterglowplus/detail" target="_blank">📻【第19回】Afterglowの夕焼けSTUDIO＋</a></div></div>
#  <div class="calendarBelt" id="row2"></div></div> <div class="calendarRow"><div class="calendarCell"><div class="calendarCellDate">17<span>日曜日</span></div><div class="calendarCellContent"></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">18<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第219回】バンドリ！ポッピンラジオ！</a>
#  <a class="calendarItem media isSp" href="https://anime.bang-dream.com/3rd/" target="_blank">📻《20:30》【第14回】BanG Dream! Presents RAISE A SUILENのRADIO R･I･O･T</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">19<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #40</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">20<span>水曜日</span></div><div class="calendarCellContent"><a class="calendarItem release isSp" href="https://bang-dream.com/discographies/2298" target="_blank">💿Roselia 11th Single「ZEAL of proud」</a>
#  <a class="calendarItem goods isSp" href="https://bushiroad-creative.com/185" target="_blank">🎵《カプセルトイ新発売》カプセル缶バッジ 2020KV ver.</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Roselia/detail" target="_blank">📻【第165回】RoseliaのRADIO SHOUT!</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">21<span>木曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《22:00》バンドリ！TV LIVE  2021 #51</a>
#  <a class="calendarItem anime isSp" href="https://anime.bang-dream.com/2nd/" target="_blank">📺《23:00》アニメ「BanG Dream! 2nd Season」#3（再）</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">22<span>金曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《21:00》Pastel＊PalettesのしゅわりんTV #19</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">23<span>土曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Afterglowplus/detail" target="_blank">📻【第20回】Afterglowの夕焼けSTUDIO＋</a>
#  <a class="calendarItem media isSp" href="https://youtu.be/afgOutBqn2M" target="_blank">🎪《21:00》【第43回】＠ハロハピCiRCLE放送局</a></div></div>
#  <div class="calendarBelt" id="row3"></div></div> <div class="calendarRow"><div class="calendarCell"><div class="calendarCellDate">24<span>日曜日</span></div><div class="calendarCellContent"></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">25<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem goods isSp" href="https://bushiroad-creative.com/186" target="_blank">🎵《カプセルトイ新発売》たまみくじ　Poppin'Party</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第220回】バンドリ！ポッピンラジオ！</a>
#  <a class="calendarItem media isSp" href="https://www.1242.com/bang_dream/" target="_blank">📻《20:30》【第15回】BanG Dream! Presents RAISE A SUILENのRADIO R･I･O･T</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">26<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #41</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">27<span>水曜日</span></div><div class="calendarCellContent"><a class="calendarItem release isSp" href="https://bang-dream.com/discographies/2299" target="_blank">💿RAISE A SUILEN 6th Single「mind of Prominence」</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Roselia/detail" target="_blank">📻【第166回】RoseliaのRADIO SHOUT!</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">28<span>木曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《22:00》バンドリ！TV LIVE 2021 #52</a>
#  <a class="calendarItem anime isSp" href="https://anime.bang-dream.com/2nd/" target="_blank">📺《23:00》アニメ「BanG Dream! 2nd Season」#4（再）</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">29<span>金曜日</span></div><div class="calendarCellContent"><a class="calendarItem goods isSp" href="https://bushiroad-creative.com/187" target="_blank">🎵《新発売》トレーディングつながるぷちアクリルスタンドSchool ver. vol.2 他</a></div></div>
#  <div class="calendarCell"><div class="calendarCellDate">30<span>土曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Afterglowplus/detail" target="_blank">📻【第21回】Afterglowの夕焼けSTUDIO＋</a></div></div>
#  <div class="calendarBelt" id="row4"></div></div> <div class="calendarRow"><div class="calendarCell"><div class="calendarCellDate">31<span>日曜日</span></div><div class="calendarCellContent"><a class="calendarItem event isSp" href="https://bang-dream.com/events/animax2021" target="_blank">🎤ANIMAX MUSIX 2021 ONLINE supported by U-NEXT</a>
#  <a class="calendarItem media isSp" href="https://www.nhk.or.jp/anisonpremium-blog/300/442374.html" target="_blank">📺《15:30》Eテレ「アニソン！プレミアム！E+」バンドリ！スペシャル放送</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">1<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.nack5.co.jp/program/afterglow795/" target="_blank">📻《0:30》【第4回】Afterglowの夕焼け STUDIO SPECIAL</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第221回】バンドリ！ポッピンラジオ！</a>
#  <a class="calendarItem media isSp" href="https://www.1242.com/bang_dream/" target="_blank">📻《20:30》【第16回】BanG Dream! Presents RAISE A SUILENのRADIO R･I･O･T</a>
#  <a class="calendarItem media isSp" href="https://twitter.com/bang_dream_info/status/1353885371973554178" target="_blank">📻《24:00》ニッポン放送「ミューコミプラス」Raychellさん＆小原莉子さん出演</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">2<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA" target="_blank">📻《21:00》モニカラジオ #42</a></div></div>
#  <div class="calendarCell notCurrent current"><div class="calendarCellDate">3<span>水曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Roselia/detail" target="_blank">📻【第167回】RoseliaのRADIO SHOUT!</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">4<span>木曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《22:00》バンドリ！TV LIVE 2021 #53</a>
#  <a class="calendarItem anime isSp" href="https://anime.bang-dream.com/2nd/" target="_blank">📺《23:00》アニメ「BanG Dream! 2nd Season」#5（再）</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">5<span>金曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📺《21:00》Pastel＊PalettesのしゅわりんTV #20</a></div></div>
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">6<span>土曜日</span></div><div class="calendarCellContent"><a class="calendarItem event isSp" href="https://bang-dream.com/events/brfes2021" target="_blank">🎤【開催延期】BUSHIROAD ROCK FESTIVAL 2021</a>
#  <a class="calendarItem media isSp" href="https://bang-dream.com/news/1121" target="_blank">📺《14:00》D4DJ×バンドリ！特別番組「ライブ振り返り配信」</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/Afterglowplus/detail" target="_blank">📻【第22回】Afterglowの夕焼けSTUDIO＋</a>
#  <a class="calendarItem media isSp" href="https://www.bsfuji.tv/choujigen/pub/index.html" target="_blank">📻《25:00》BSフジ「オダイバ!! 超次元音楽祭 -2020無観客でも心はひとつ!!編 -」Poppin'Party出演</a></div></div>
#  <div class="calendarBelt" id="row5"></div></div> </div>
#  </div>

# %%
# calendarCellでイベント情報をごっそりとってくる
calendarCell = soup.find_all(class_="calendarCell")
calendarCell
# Out:
# [<div class="calendarCell notCurrent"><div class="calendarCellDate">27<span>日曜日</span></div><div class="calendarCellContent"><a class="calendarItem isSp" href="https://bang-dream.bushimo.jp/character/maruyama-aya/" target="_blank">🍰丸山 彩　誕生日</a></div></div>,
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">28<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.nack5.co.jp/program/afterglow795/" target="_blank">📻《0:30》【第3回】Afterglowの夕焼けSTUDIO SPECIAL</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第216回】バンドリ！ポッピンラジオ！</a></div></div>,
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">29<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #37</a></div></div>,
# ...

# %%
# calendarCell notCurrentで先月来月の情報をとってくる
calendarCell_notCurrent = soup.find_all(class_="calendarCell notCurrent")
calendarCell_notCurrent
# Out:
# [<div class="calendarCell notCurrent"><div class="calendarCellDate">27<span>日曜日</span></div><div class="calendarCellContent"><a class="calendarItem isSp" href="https://bang-dream.bushimo.jp/character/maruyama-aya/" target="_blank">🍰丸山 彩　誕生日</a></div></div>,
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">28<span>月曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.nack5.co.jp/program/afterglow795/" target="_blank">📻《0:30》【第3回】Afterglowの夕焼けSTUDIO SPECIAL</a>
#  <a class="calendarItem media isSp" href="https://hibiki-radio.jp/description/poppin-radio/detail" target="_blank">📻【第216回】バンドリ！ポッピンラジオ！</a></div></div>,
#  <div class="calendarCell notCurrent"><div class="calendarCellDate">29<span>火曜日</span></div><div class="calendarCellContent"><a class="calendarItem media isSp" href="https://www.youtube.com/channel/UCN-bFIdJM0gQlgX7h6LKcZA?spfreload=5" target="_blank">📻《21:00》モニカラジオ #37</a></div></div>,
# ...

# %%
remake = [info for info in calendarCell if info not in calendarCell_notCurrent]

# %%
calendar_yotei = {}

for info in remake:
    # 日付と曜日情報
    day = info.find(class_="calendarCellDate").get_text()
    date = int(day[:-3])
    yobi = day[-3:]
    
    # 予定情報
    yotei = []
    for link in info.find(class_="calendarCellContent").find_all("a"):
        text,url_link = link.get_text(),link.get("href")
        yotei.append({"text":text, "url_link":url_link})
        
    calendar_yotei[date] = {"date":date, "yobi":yobi, "yotei":yotei}

calendar_yotei
# Out:
# {1: {'date': 1, 'yobi': '金曜日', 'yotei': []},
#  2: {'date': 2,
#   'yobi': '土曜日',
#   'yotei': [{'text': '🎍《22:00》朝までバンドリ！TV 2021',
#     'url_link': 'https://bang-dream.com/news/1095'},
#    {'text': '📻【第14回】Afterglowの夕焼けSTUDIO＋',
#     'url_link': 'https://hibiki-radio.jp/description/Afterglowplus/detail'}]},
#  3: {'date': 3,
#   'yobi': '水曜日',
#   'yotei': [{'text': '📻【第167回】RoseliaのRADIO SHOUT!',
#     'url_link': 'https://hibiki-radio.jp/description/Roselia/detail'}]},
#  4: {'date': 4,
#   'yobi': '月曜日',
#   'yotei': [{'text': '🎫【申込締切】「Rausch und/and Craziness Ⅱ」ブシロードミュージックパスポート先行',
#     'url_link': 'https://bang-dream.com/events/ruc2'},
#    {'text': '🎫【申込締切】「Astral Harmony」ブシロードミュージックパスポート先行',
#     'url_link': 'https://bang-dream.com/events/astralharmony'},
#    {'text': '📻【第217回】バンドリ！ポッピンラジオ！',
#     'url_link': 'https://hibiki-radio.jp/description/poppin-radio/detail'},
#    {'text': '📻《20:30》【第12回】BanG Dream! Presents RAISE A SUILEN のRADIO R･I･O･T',
# ...

# %% [markdown]
# これをいい感じにグーグルカレンダーの入力形式にぶち込む

# %% [markdown]
# https://support.google.com/a/users/answer/37118?hl=ja&co=GENIE.Platform%3DDesktop#zippy=%2Ccsv-%E3%83%95%E3%82%A1%E3%82%A4%E3%83%AB%E3%81%AE%E4%BD%9C%E6%88%90%E3%81%A8%E7%B7%A8%E9%9B%86

# %% [markdown]
# ふーーーーーん

# %% [markdown]
# 時間情報抜き取るのめんどくさいから、全日指定でいっか

# %% [markdown]
# - **`Subject`**
#   予定の名前（必須）。
#   例: **`期末試験`**
# - **`Start Date`**
#   予定の開始日（必須）。
#   例: **`05/30/2020`**
# - **`Start Time`**
#   予定の開始時刻。
#   例: **`10:00 AM`**
# - **`End Date`**
#   予定の終了日。
#   例: `05/30/2020`
# - **`End Time`**
#   予定の終了時刻。
#   例: **`1:00 PM`**
# - **`All Day Event`**
#   終日の予定であるかどうかを指定します。終日の予定の場合は **`True`**、そうでない場合は **`False`** と入力します。
#   例: **`False`**
# - **`Description`**
#   予定の説明やメモ。
#   例: `**選択式問題 50 問と論文 2,000 字** `
# - **`Location`**
#   予定の場所。
#   例: **`"614 教室"`**
# - **`Private`**
#   予定を限定公開にするかどうかを指定します。予定が限定公開の場合は **`True`**、そうでない場合は **`False`** と入力します。
#   例: **`True`**

# %% [markdown]
# 今回は**`Subject`**と**`Start Date`**と**`Description`**と**`Private`**だけでいいか

# %% [markdown]
# わざわざPandasで作る必要もないな

# %%
header = "Subject,Start Date,Description,Private\n"

with open("bang_dream_schedule_"+str(year)+niketa(month)+".csv","w",encoding="utf8") as f:
    f.write(header)

    for info in calendar_yotei.values():
        # 予定が無かったらcontinue
        if len(info["yotei"]) == 0:
            continue

        # print(info)

        # 日付合成（DD/MM/YYYY）
        Start_Date = niketa(info["date"]) + "/" + niketa(month) + "/" + str(year)

        # print(Start_Date)
        
        for subject in info["yotei"]:
            f.write(subject["text"] + "," + Start_Date + "," + subject["url_link"]+",False\n") # 限定公開にすると共有したときに内容が見れない

        # break

# %% [markdown]
# なんかエクセルで開くとキレられる

# %%
import pandas as pd

pd.read_csv("bang_dream_schedule_202101.csv")
# Out:
#                                               Subject  Start Date  \
# 0                             🎍《22:00》朝までバンドリ！TV 2021  02/01/2021
# 1                         📻【第14回】Afterglowの夕焼けSTUDIO＋  02/01/2021
# 2                        📻【第167回】RoseliaのRADIO SHOUT!  03/01/2021
# 3   🎫【申込締切】「Rausch und/and Craziness Ⅱ」ブシロードミュージック...  04/01/2021
# 4           🎫【申込締切】「Astral Harmony」ブシロードミュージックパスポート先行  04/01/2021
# 5                               📻【第217回】バンドリ！ポッピンラジオ！  04/01/2021
# 6   📻《20:30》【第12回】BanG Dream! Presents RAISE A SUI...  04/01/2021
# 7                                  📻《21:00》モニカラジオ #38  05/01/2021
# 8               💿Poppin'Party 16th Single「Photograph」  06/01/2021
# 9                        📻【第163回】RoseliaのRADIO SHOUT!  06/01/2021
# 10                      📺《22:00》バンドリ！TV LIVE 2021 #49  07/01/2021
# 11           📺《23:00》アニメ「BanG Dream! 2nd Season」#1（再）  07/01/2021
# 12                                         🍰羽沢つぐみ　誕生日  07/01/2021
# ...

# %% [markdown]
# 出来てるよな

# %% [markdown]
# ![image.png](attachment:aa5d798b-7441-428d-a7fd-37c23207d119.png)

# %% [markdown]
# 天才（感動）
